# %%
# Imports
from __future__ import print_function
import torch
cuda = torch.cuda.is_available()
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append("../../semi-supervised")

DEVICE = torch.device("cuda")
BATCH_SIZE = 64
ANALYTICAL_KLD = True
EPOCHS = 50

# %% [markdown]
# # Variational Autoencoder
#
# The variational autoencoder (VAE) was described in its current form in [Kingma 2013](https://arxiv.org/abs/1312.6114). The model consists of an encoder/inference network $q_{\phi}(z|x)$ and a decoder/generative network $p_{\theta}(x|z)$. The main idea is that it is possible to both reconstruct and generate samples from from some input distribution by learning a variational distribution over the latent variable $z$.
#
# <img src="../images/vae.png" width="300px"/>
#
# The VAE therefore has a bottleneck structure, where the input $x$ is encoded into a latent variable $z$. New data can then be generated by feeding a latent code into the generator network - $\widehat{x} \sim p_{\theta}(z|x)$. The diagram above shows the generative model (right) and how the latent variable $z$ is inferred from $x$ (left).
#
# Below we will instantiate a new variational autoencoder with this bottleneck structure consisting of a 2-layer encoder network turning an input MNIST image into a latent code: $784 \to 256 \to 128 \to 32$. We also have a decoder that performs the operation in reverse: $32 \to 128 \to 256 \to 784$.

# %%
from models import VariationalAutoencoder
from layers import GaussianSample
model = VariationalAutoencoder([784, 32, [256, 128]]).to(DEVICE)
model
# Out:
# VariationalAutoencoder(
#   (encoder): Encoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=784, out_features=256, bias=True)
#       (1): Linear(in_features=256, out_features=128, bias=True)
#     )
#     (sample): GaussianSample(
#       (mu): Linear(in_features=128, out_features=32, bias=True)
#       (log_var): Linear(in_features=128, out_features=32, bias=True)
#     )
#   )
#   (decoder): Decoder(
#     (hidden): ModuleList(
#       (0): Linear(in_features=32, out_features=128, bias=True)
#       (1): Linear(in_features=128, out_features=256, bias=True)
#     )
#     (reconstruction): Linear(in_features=256, out_features=784, bias=True)
#     (output_activation): Sigmoid()
#   )
# )

# %% [markdown]
# Notice how the middle most layer consists of a `GaussianSample` layer, in which we turn the input digit into the parameters of a Normal distribution with parameters $\mu$ and $\sigma$. This allows us to use the *reparametrization trick* to sample from this distribution to introduce stochasticity into the network.

# %%
gaussian = GaussianSample(10, 1)
z, mu, log_var = gaussian(torch.ones(1, 10))

print('sample', z)
print('from Normal(', mu, ',', log_var.exp(), ')')
# Out:
# sample tensor(1.00000e-02 *
#        [[-7.8124]])
# from Normal( tensor([[-0.6146]]) , tensor([[ 1.9360]]) )

# %% [markdown]
# ## Training
#
# How do we go about training a variational autoencoder then? We want to model the data distribution $p(x)$, from here we can introduce a variational distribution $q(z|x)$ by multiplying and dividing by this distribution. Now we employ Jensen's inequality to move the logarithm inside the integral, we can do this because $\log$ is concave and because $q(z|x)$ is a probability distribution. From here on we just rearrange and we see that a lower bound on the marginal probability of the data $p(x)$ is just an expectation over the likelihood of the data minus the KL-divergence between the variational distribution and a prior $p(z)$.
#
# \begin{align}
# \log p(x) &= \log \int p(x, z) \ dz = \log \int q(z|x) \frac{p(x, z)}{q(z|x)} \ dz\\
#           &\geq \int q(z|x) \log \frac{p(x, z)}{q(z|x)} \ dz = \int q(z|x) \log p(x|z) + \log \frac{p(z)}{q(z|x)} \ dz\\
#           &= \int q(z|x) \log p(x|z) \ dz + \int q(z|x) \log \frac{p(z)}{q(z|x)} \ dz\\
#           &= \mathbb{E}_{q(z|x)} [\log p(x|z)] - KL(q(z|x)||p(z)) = \mathcal{L}(x)
# \end{align}
#
# To make things even more concrete, we show how we can go from this equation to an actual algorithm. Recall that the expectation is just an arithmetic mean, which can be approximated using Monte-Carlo samples. In fact for most applications we can do with just a single sample, even though this provides infinite variance.
#
# $$\mathbb{E}_{q(z|x)} [\log p(x|z)] = \lim_{N \to \infty} \frac{1}{N} \sum_{i=1}^{N} \log p(x_i|z_i) \approx \frac{1}{M} \sum_{i=1}^{M} \log p(x_i|z_i)$$
#
# As you can see the likelihood is just the log probability of the data given the latent variable, but the latent variable is itself derived from the data - we can just use the reconstruction error! In the MNIST case, it is most fitting to use the Bernoulli / binary cross entropy.
#
# Finally, the second term is the Kullback-Leibler divergence. It states that whatever distribution we learn over $q(z|x)$ can never be very far from the prior $p(z)$. This is both good and bad news. Ideally we want a reconstruction that is as good as possible, i.e. only relying on the likelihood, which will only occur if $q(z|x) = p(z)$. This will never happen in practice as the q-distribution will be very complex in order to produce latent variables that result convincing samples. On the plus side, the KL-term acts as a regularizer that pulls the distribution towards the prior, which is the whole reason why we can create samples.
#
# This term can either be computed analytically, or by sampling similarly to the way we did it in the expectation, which you can see in the printed doc string below.

# %%
print(model._kld.__doc__)
# Out:
#         Computes the KL-divergence of
#         some element z.
#
#         KL(q||p) = -∫ q(z) log [ p(z) / q(z) ]
#                  = -E[log p(z) - log q(z)]
#
#         :param z: sample from q-distribuion
#         :param q_param: (mu, log_var) of the q-distribution
#         :param p_param: (mu, log_var) of the p-distribution
#         :return: KL(q||p)

# %%
# prepare dataset
import torch.utils.data
from torchvision import datasets, transforms
kwargs = {'num_workers': 1, 'pin_memory': True} 
flatten = lambda x: transforms.ToTensor()(x).view(-1)
train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../../data', train=True, download=True,
                   transform=flatten),
    batch_size=BATCH_SIZE, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('../../data', train=False, download=True,
                   transform=flatten),
    batch_size=BATCH_SIZE, shuffle=False, **kwargs)

optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, betas=(0.9, 0.999))

# %%
import torch.nn.functional as F
def binary_cross_entropy(r, x):
    return -torch.sum(x * torch.log(r + 1e-8) + (1 - x) * torch.log(1 - r + 1e-8), dim=-1)
def train(epoch):
    model.train()
    train_loss = 0
    train_kl = 0
    for (u, _) in train_loader:
        u = u.to(DEVICE)

        reconstruction = model(u)
        
        likelihood = -binary_cross_entropy(reconstruction, u)
        elbo = likelihood - model.kl_divergence
        
        L = -torch.mean(elbo)

        L.backward()
        optimizer.step()
        optimizer.zero_grad()

        train_kl += torch.sum(model.kl_divergence).item()
        train_loss += L.item() * BATCH_SIZE

    if epoch % 1 == 0:
        print("Epoch: {} | loss: {:5.2f} kl: {:5.2f}".
              format(epoch, train_loss/len(train_loader.dataset), train_kl/len(train_loader.dataset)))
def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for batch_idx, (data, _) in enumerate(test_loader):
            data = data.to(DEVICE)
            reconstruction = model(data)
            likelihood = -binary_cross_entropy(reconstruction, data)
            elbo = likelihood - model.kl_divergence
            L = -torch.sum(elbo)
            test_loss += L.item()
        print("Epoch: {} | test loss: {:.2f}".format(epoch, test_loss/len(test_loader.dataset)))

# %% [markdown]
# Note that the likelihood here involves multi-target loss, so `nn.BCELoss` and `F.bianry_cross_entropy` cannot be directly used here.

# %%
for epoch in range(1, EPOCHS + 1):
    train(epoch)
    test(epoch)
# Out:
# Epoch: 1 | loss: 191.29
# Epoch: 1 | test loss: 159.03
# Epoch: 2 | loss: 154.43
# Epoch: 2 | test loss: 148.91
# Epoch: 3 | loss: 147.61
# Epoch: 3 | test loss: 144.57
# Epoch: 4 | loss: 144.14
# Epoch: 4 | test loss: 141.55
# Epoch: 5 | loss: 141.84
# Epoch: 5 | test loss: 139.91
# Epoch: 6 | loss: 140.14
# Epoch: 6 | test loss: 138.08
# Epoch: 7 | loss: 138.74
# Epoch: 7 | test loss: 137.13
# Epoch: 8 | loss: 137.65
# Epoch: 8 | test loss: 136.80
# Epoch: 9 | loss: 136.76
# Epoch: 9 | test loss: 135.44
# Epoch: 10 | loss: 135.97
# Epoch: 10 | test loss: 134.70
# Epoch: 11 | loss: 135.41
# Epoch: 11 | test loss: 133.99
# Epoch: 12 | loss: 134.85
# Epoch: 12 | test loss: 133.34
# Epoch: 13 | loss: 134.29
# Epoch: 13 | test loss: 133.58
# Epoch: 14 | loss: 133.86
# Epoch: 14 | test loss: 132.99
# Epoch: 15 | loss: 133.54
# Epoch: 15 | test loss: 132.60
# Epoch: 16 | loss: 133.21
# Epoch: 16 | test loss: 132.40
# Epoch: 17 | loss: 132.86
# Epoch: 17 | test loss: 132.11
# Epoch: 18 | loss: 132.65
# Epoch: 18 | test loss: 131.95
# Epoch: 19 | loss: 132.34
# Epoch: 19 | test loss: 132.01
# Epoch: 20 | loss: 132.11
# Epoch: 20 | test loss: 131.21
# Epoch: 21 | loss: 131.88
# Epoch: 21 | test loss: 131.40
# Epoch: 22 | loss: 131.72
# Epoch: 22 | test loss: 130.81
# Epoch: 23 | loss: 131.44
# Epoch: 23 | test loss: 130.50
# Epoch: 24 | loss: 131.34
# Epoch: 24 | test loss: 130.32
# Epoch: 25 | loss: 131.18
# Epoch: 25 | test loss: 130.44
# Epoch: 26 | loss: 130.93
# Epoch: 26 | test loss: 130.23
# Epoch: 27 | loss: 130.77
# Epoch: 27 | test loss: 129.97
# Epoch: 28 | loss: 130.65
# Epoch: 28 | test loss: 130.14
# Epoch: 29 | loss: 130.56
# Epoch: 29 | test loss: 130.24
# Epoch: 30 | loss: 130.36
# Epoch: 30 | test loss: 129.79
# Epoch: 31 | loss: 130.19
# Epoch: 31 | test loss: 129.58
# Epoch: 32 | loss: 130.09
# Epoch: 32 | test loss: 129.52
# Epoch: 33 | loss: 130.12
# Epoch: 33 | test loss: 129.63
# Epoch: 34 | loss: 130.04
# Epoch: 34 | test loss: 129.14
# Epoch: 35 | loss: 129.81
# Epoch: 35 | test loss: 129.16
# Epoch: 36 | loss: 129.67
# Epoch: 36 | test loss: 129.26
# Epoch: 37 | loss: 129.67
# Epoch: 37 | test loss: 129.09
# Epoch: 38 | loss: 129.52
# Epoch: 38 | test loss: 129.24
# Epoch: 39 | loss: 129.48
# Epoch: 39 | test loss: 128.81
# Epoch: 40 | loss: 129.35
# Epoch: 40 | test loss: 128.82
# Epoch: 41 | loss: 129.25
# Epoch: 41 | test loss: 128.53
# Epoch: 42 | loss: 129.20
# Epoch: 42 | test loss: 128.71
# Epoch: 43 | loss: 129.09
# Epoch: 43 | test loss: 128.35
# Epoch: 44 | loss: 129.06
# Epoch: 44 | test loss: 128.52
# Epoch: 45 | loss: 128.88
# Epoch: 45 | test loss: 128.42
# Epoch: 46 | loss: 128.84
# Epoch: 46 | test loss: 128.20
# Epoch: 47 | loss: 128.79
# Epoch: 47 | test loss: 128.41
# Epoch: 48 | loss: 128.76
# Epoch: 48 | test loss: 128.26
# Epoch: 49 | loss: 128.64
# Epoch: 49 | test loss: 128.11
# Epoch: 50 | loss: 128.49
# Epoch: 50 | test loss: 128.27

# %% [markdown]
# ## Sampling from the generative model  (sampling from the prior)
#
# Now that we have trained the network, we can begin to sample from it. We simply give it some random noise distributed according to the prior $p(z) = \mathcal{N}(0, I)$ and send it through the decoder. This process generates a slew of samples that look like they come from the original distribution $p(x)$.

# %%
with torch.no_grad():
    model.eval()
    samples = model.sample(torch.randn(16, 32).to(DEVICE))
    f, axarr = plt.subplots(1, 16, figsize=(18, 12))
    samples = samples.view(-1, 28, 28).cpu().numpy()
    
    for i, ax in enumerate(axarr.flat):
        ax.imshow(samples[i])
        ax.axis("off")

# %% [markdown]
# ## Conditional Generation (sampling from the posterior)
#
# To generate samples conditioned on a given digit. We can simply first get the poesterior $p(z|x)$ of a given sample, and generate new digits based on samples drawn from $p(z|x)$.

# %%
# generate 15 samples given a single digit
for batch_idx, (data, label) in enumerate(test_loader):
    break
print('The first column is the given gold sample.')
with torch.no_grad():
    for digit in range(10):
        for i in range(label.size(0)):
            if torch.max(label[i]).item() == digit:
                sample = data[i].unsqueeze(0)
                x = sample.expand(15, 784).to(DEVICE)
                z, _, _ = model.encoder(x)
                samples = model.sample(z)
                samples = torch.cat([sample.view(-1, 28, 28), samples.view(-1, 28, 28).cpu()])
                samples = samples.numpy()
                f, axarr = plt.subplots(1, 16, figsize=(18, 12))
                for i, ax in enumerate(axarr.flat):
                    ax.imshow(samples[i])
                    ax.axis("off")  
                break
# Out:
# The first column is the given gold sample.

# %% [markdown]
# ## Side note: Normalizing flows
#
# We can get a more expressive variational approximation by using flows. In the regular variational autoencoder we are limited to a diagonal Gaussian distribution as the output of our encoder, but we can do better. Introducing a full-rank covariance matrix would be an option, but we will quickly see that it becomes computationally infeasible.
#
# What we instead can do is to use change-of-variables to calculate the probability of a random sample under some transformation. In fact, if this transformation is made in a specific way, it is simple to calculate the probability of a sample under a series of $K$ transforms.
#
# $$\ln q_K(z_K) = \ln q_0(z_0) − \sum_{k=1}^{K} \ln \bigg | \det \frac{\partial f_k}{\partial z_{k-1}} \bigg |$$
#
# This is the essence of [Normalizing Flows (Rezende & Mohammed, 2015)](https://arxiv.org/abs/1505.05770). This process increases the expressability of the variational distribution and will likely give a better estimate of the marginal likelihood of the data $p(x)$. However, the parameters of each flow must be learned, meaning that this process will take a long time in order to perform well.

# %%
from layers import NormalizingFlows
from models import VariationalAutoencoder
from layers import GaussianSample

# Add a series of 16 normalizing flows to the model
# You can do this to *all* of the models in the library.

# Rebuild the model
model = VariationalAutoencoder([784, 32, [256, 128]]).to(DEVICE)
flow = NormalizingFlows(32, n_flows=16).to(DEVICE)
model.add_flow(flow)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4, betas=(0.9, 0.999))

# %%
for epoch in range(1, EPOCHS + 1):
    train(epoch)
    test(epoch)
# Out:
# Epoch: 1 | loss: 460.78 kl: 245.28
# Epoch: 1 | test loss: 510.64
# Epoch: 2 | loss: 361.62 kl: 165.79
# Epoch: 2 | test loss: 307.64
# Epoch: 3 | loss: 252.38 kl: 63.24
# Epoch: 3 | test loss: 255.92
# Epoch: 4 | loss: 202.60 kl: 20.63
# Epoch: 4 | test loss: 167.03
# Epoch: 5 | loss: 161.16 kl: -11.87
# Epoch: 5 | test loss: 133.12
# Epoch: 6 | loss: 118.17 kl: -48.21
# Epoch: 6 | test loss: 114.50
# Epoch: 7 | loss: 101.96 kl: -59.84
# Epoch: 7 | test loss: 89.59
# Epoch: 8 | loss: 79.29 kl: -77.01
# Epoch: 8 | test loss: 54.03
# Epoch: 9 | loss: 44.85 kl: -107.75
# Epoch: 9 | test loss: 35.42
# Epoch: 10 | loss: 28.09 kl: -122.34
# Epoch: 10 | test loss: 18.03
# Epoch: 11 | loss: 14.04 kl: -133.65
# Epoch: 11 | test loss: 11.02
# Epoch: 12 | loss: -11.12 kl: -156.82
# Epoch: 12 | test loss: -21.00
# Epoch: 13 | loss: -26.28 kl: -171.10
# Epoch: 13 | test loss: -37.15
# Epoch: 14 | loss: -43.13 kl: -185.78
# Epoch: 14 | test loss: -49.63
# Epoch: 15 | loss: -60.53 kl: -202.10
# Epoch: 15 | test loss: -69.18
# Epoch: 16 | loss: -74.27 kl: -213.93
# Epoch: 16 | test loss: -82.71
# Epoch: 17 | loss: -86.17 kl: -224.48
# Epoch: 17 | test loss: -94.66
# Epoch: 18 | loss: -94.29 kl: -232.19
# Epoch: 18 | test loss: -102.26
# Epoch: 19 | loss: -107.30 kl: -243.46
# Epoch: 19 | test loss: -117.62
# Epoch: 20 | loss: -117.01 kl: -252.70
# Epoch: 20 | test loss: -122.33
# Epoch: 21 | loss: -127.41 kl: -262.23
# Epoch: 21 | test loss: -132.30
# Epoch: 22 | loss: -140.17 kl: -273.66
# Epoch: 22 | test loss: -141.54
# Epoch: 23 | loss: -151.48 kl: -284.36
# Epoch: 23 | test loss: -159.58
# Epoch: 24 | loss: -162.74 kl: -294.70
# Epoch: 24 | test loss: -168.33
# Epoch: 25 | loss: -175.72 kl: -307.00
# Epoch: 25 | test loss: -180.01
# Epoch: 26 | loss: -186.89 kl: -318.65
# Epoch: 26 | test loss: -196.89
# Epoch: 27 | loss: -206.33 kl: -336.75
# Epoch: 27 | test loss: -225.27
# Epoch: 28 | loss: -229.37 kl: -359.48
# Epoch: 28 | test loss: -240.85
# Epoch: 29 | loss: -249.61 kl: -379.06
# Epoch: 29 | test loss: -256.46
# Epoch: 30 | loss: -267.17 kl: -396.24
# Epoch: 30 | test loss: -276.36
# Epoch: 31 | loss: -284.48 kl: -412.68
# Epoch: 31 | test loss: -290.96
# Epoch: 32 | loss: -302.20 kl: -430.38
# Epoch: 32 | test loss: -309.05
# Epoch: 33 | loss: -320.64 kl: -448.10
# Epoch: 33 | test loss: -330.14
# Epoch: 34 | loss: -338.16 kl: -464.57
# Epoch: 34 | test loss: -346.13
# Epoch: 35 | loss: -356.60 kl: -483.16
# Epoch: 35 | test loss: -369.09
# Epoch: 36 | loss: -373.42 kl: -499.48
# Epoch: 36 | test loss: -379.72
# Epoch: 37 | loss: -394.98 kl: -521.52
# Epoch: 37 | test loss: -407.10
# Epoch: 38 | loss: -416.03 kl: -542.56
# Epoch: 38 | test loss: -427.00
# Epoch: 39 | loss: -433.27 kl: -559.46
# Epoch: 39 | test loss: -444.95
# Epoch: 40 | loss: -452.74 kl: -578.84
# Epoch: 40 | test loss: -464.47
# Epoch: 41 | loss: -468.89 kl: -594.58
# Epoch: 41 | test loss: -480.59
# Epoch: 42 | loss: -490.37 kl: -616.12
# Epoch: 42 | test loss: -499.77
# Epoch: 43 | loss: -510.31 kl: -635.92
# Epoch: 43 | test loss: -519.54
# Epoch: 44 | loss: -526.92 kl: -652.40
# Epoch: 44 | test loss: -534.97
# Epoch: 45 | loss: -540.58 kl: -665.41
# Epoch: 45 | test loss: -546.87
# Epoch: 46 | loss: -555.36 kl: -679.80
# Epoch: 46 | test loss: -563.66
# Epoch: 47 | loss: -567.83 kl: -691.75
# Epoch: 47 | test loss: -577.24
# Epoch: 48 | loss: -579.80 kl: -703.52
# Epoch: 48 | test loss: -585.94
# Epoch: 49 | loss: -596.45 kl: -719.72
# Epoch: 49 | test loss: -602.98
# Epoch: 50 | loss: -607.84 kl: -730.97
# Epoch: 50 | test loss: -614.14

# %% [markdown]
# # Why negative loss here ?

# %% [markdown]
# ## Sampling from the prior

# %%
with torch.no_grad():
    model.eval()
    samples = model.sample(torch.randn(16, 32).to(DEVICE))
    f, axarr = plt.subplots(1, 16, figsize=(18, 12))
    samples = samples.view(-1, 28, 28).cpu().numpy()
    
    for i, ax in enumerate(axarr.flat):
        ax.imshow(samples[i])
        ax.axis("off")

# %% [markdown]
# ## Sampling from the posterior

# %%
# generate 15 samples given a single digit
for batch_idx, (data, label) in enumerate(test_loader):
    break
print('The first column is the given sample.')
with torch.no_grad():
    for digit in range(10):
        for i in range(label.size(0)):
            if label[i].item() == digit:
                sample = data[i].unsqueeze(0)
                x = sample.expand(15, 784).to(DEVICE)
                z, _, _ = model.encoder(x)
                samples = model.sample(z)
                samples = torch.cat([sample.view(-1, 28, 28), samples.view(-1, 28, 28).cpu()])
                samples = samples.numpy()
                f, axarr = plt.subplots(1, 16, figsize=(18, 12))
                for i, ax in enumerate(axarr.flat):
                    ax.imshow(samples[i])
                    ax.axis("off")  
                break
# Out:
# The first column is the given sample.

# %% [markdown]
# ## Additional tips
#
# If you want to work with a problem in which the data distribution $x$ is continuous, you can do so by changing the output activation of the decoder and using a different likelihood function, as shown below.

# %%
import torch.nn as nn

model.decoder.output_activation = nn.Softmax()
loss = nn.CrossEntropyLoss()
